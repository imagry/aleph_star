# %%
# this can take some time...
import Statistics: median
using Test
using Plots
pyplot()
include("aleph_star/aleph_star.jl")
include("env/env_lane.jl")
include("ml/ml.jl")
include("ml/train_alephstar.jl");
include("ml/train_dqn.jl");
include("test.jl")
# Out:
# LoadError: invalid redefinition of constant Node
# in expression starting at /home/skariel/prog/MLR_MONOREPO/Ariel/jl/alef_star/aleph_star/data_structures.jl:2
#
# Stacktrace:
#  [1] top-level scope at none:0
#  [2] include at ./boot.jl:317 [inlined]
#  [3] include_relative(::Module, ::String) at ./loading.jl:1041
#  [4] include(::Module, ::String) at ./sysimg.jl:29
#  [5] include(::String) at ./client.jl:388
#  [6] top-level scope at none:0
#  [7] include at ./boot.jl:317 [inlined]
#  [8] include_relative(::Module, ::String) at ./loading.jl:1041
#  [9] include(::Module, ::String) at ./sysimg.jl:29
#  [10] include(::String) at ./client.jl:388
#  [11] top-level scope at In[2]:6
# WARNING: both Distributions and Knet export "params"; uses of it in module Main must be qualified

# %%
occursin("1","123")
# Out:
# true

# %%
PTH = "/media/skariel/store/data/aleph_zero_data"
val_dtas = Vector{Float32}[]
val_dtdqn = Vector{Float32}[]
for fn in readdir(PTH)
    @show fn
    fn = joinpath(PTH, fn)
    if occursin("dtas",fn)
        @load fn dtas
        push!(val_dtas, dtas.val_rewards)
    else
        @load fn dtdqn
        push!(val_dtdqn, dtdqn.val_rewards)
        @show dtdqn.epsilon0
    end
end
# Out:
# fn = "_dtas.jld2"
# fn = "a_dtas3.jld2"
# fn = "dtas.jld2"
# fn = "dtas2.jld2"
# fn = "dtas3.jld2"
# fn = "dtas4.jld2"
# fn = "dtdqn.jld2"
# ┌ Warning: type Main.DemoTrainingDQN does not exist in workspace; reconstructing
# └ @ JLD2 /home/skariel/.julia/packages/JLD2/KjBIK/src/data.jl:1153
# dtdqn.epsilon0 = 1.0
# fn = "dtdqn2.jld2"
# ┌ Warning: type Main.DemoTrainingDQN does not exist in workspace; reconstructing
# └ @ JLD2 /home/skariel/.julia/packages/JLD2/KjBIK/src/data.jl:1153
# dtdqn.epsilon0 = 1.0
# fn = "dtdqn3.jld2"
# ┌ Warning: type Main.DemoTrainingDQN does not exist in workspace; reconstructing
# └ @ JLD2 /home/skariel/.julia/packages/JLD2/KjBIK/src/data.jl:1153
# dtdqn.epsilon0 = 0.5
# fn = "dtdqn4.jld2"
# ┌ Warning: type Main.DemoTrainingDQN does not exist in workspace; reconstructing
# └ @ JLD2 /home/skariel/.julia/packages/JLD2/KjBIK/src/data.jl:1153
# dtdqn.epsilon0 = 0.5

# %%
plot(1 .+moving_avg(val_dtas[1], 100), lc=:red, label="A0")
plot!(1 .+moving_avg(val_dtas[2], 100), lc=:red, label=false)
#plot!(1 .+moving_avg(val_dtas[3], 100), lc=:red)
plot!(1 .+moving_avg(val_dtas[4], 100), lc=:red)
plot!(1 .+moving_avg(val_dtas[5], 100), lc=:red)
plot!(1 .+moving_avg(val_dtas[6], 100), lc=:red)

plot!(1 .+moving_avg(val_dtdqn[1], 100), lc=:green)
plot!(1 .+moving_avg(val_dtdqn[2], 100), lc=:blue)
plot!(1 .+moving_avg(val_dtdqn[3], 100), lc=:blue)
plot!(1 .+moving_avg(val_dtdqn[4], 100), lc=:blue, yaxis=:log, ylims=(100,2.5e5), xlims=(1,1000), leg=false)

# %%
length(val_dtdqn)
# Out:
# 4

# %%
dtdqn
