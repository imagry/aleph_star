# %% [markdown]
# # setting up environment

# %%
# this can take some time...
import Statistics: median
using Test
using Plots
pyplot()
include("aleph_star/aleph_star.jl")
include("env/env_lane.jl")
include("ml/ml.jl")
include("ml/train_alephstar.jl");
include("test.jl")
# Out:
# test (generic function with 1 method)

# %%
state, env = initialize_simple_road();
sensors = get_sensors(env,state);
heatmap(sensors[:,:,1,1], aspect_ratio = 1.0)

# %%
test()
# Out:
# ...........................
# [V] all tests passed!

# %% [markdown]
# # Train

# %%
dtas = InitializeDTAS();

# %%
iters = 1000
fname = "dtas_tst.jld2"
traindtas(dtas, iters, fname)
# Out:
# --------------------------------------------------------------- i=1
# ...........................
#
# ---- training for 1221 iterations
# ............
# (length(dtas.qs), length(ixs)) = (80000, 3908)
#       eps   = 0.3646    gamma=0.98
#  tree_rnk   = 3192    mvel    = 10.3279    svel = 2.0408
# val_steps   = 1933    mvel    = 10.3992    svel = 1.7149
# tree_passed = 169    vpassed = 101
# --------------------------------------------------------------- i=2
# ...........................
#
# ---- training for 1224 iterations
# ............
# (length(dtas.qs), length(ixs)) = (80000, 3916)
#       eps   = 0.3628    gamma=0.98
#  tree_rnk   = 3218    mvel    = 10.5688    svel = 1.9195
# val_steps   = 215    mvel    = 9.4573    svel = 2.3668
# tree_passed = 179    vpassed = 9
# --------------------------------------------------------------- i=3
# ...........................
#
# ---- training for 1202 iterations
# ............
# (length(dtas.qs), length(ixs)) = (80000, 3847)
#       eps   = 0.361    gamma=0.98
#  tree_rnk   = 2988    mvel    = 10.2579    svel = 1.7341
# val_steps   = 1684    mvel    = 9.9242    svel = 2.1786
# tree_passed = 160    vpassed = 80
# --------------------------------------------------------------- i=4
# ........

# %%
plotdtas(dtas)

# %%
histogram(dtas.priorities, xlims=(0,sort(dtas.priorities)[floor(Int64, 0.9*length(dtas.priorities))]))

# %%
@save fname dtas
